jpg
#   inflating: splits_v3/augmented_data/paper/aug_6639_paper_2747.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2714.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2751.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2769.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6648_paper_2761.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2754.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2786.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6641_paper_2753.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6644_paper_2756.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2794.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2798.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2734.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6637_paper_2747.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2711.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6640_paper_2753.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6632_paper_2730.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2771.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6624_paper_2719.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2741.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6635_paper_2746.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6626_paper_2720.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6636_paper_2746.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6627_paper_2720.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2665.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2707.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6630_paper_2721.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2696.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6643_paper_2756.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6631_paper_2730.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2662.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6619_paper_2717.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2695.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6628_paper_2721.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2638.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6621_paper_2717.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2669.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6633_paper_2730.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6634_paper_2746.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6622_paper_2719.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2596.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2641.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6617_paper_2712.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6623_paper_2719.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2677.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2566.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6618_paper_2712.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6613_paper_2704.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2565.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6629_paper_2721.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6620_paper_2717.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2689.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2545.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6625_paper_2720.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6616_paper_2712.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2648.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2581.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6645_paper_2756.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2602.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6614_paper_2704.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2540.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2615.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6611_paper_2691.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2544.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6608_paper_2690.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6615_paper_2704.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2510.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2525.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6609_paper_2690.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6610_paper_2691.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2628.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2539.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2614.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2507.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2468.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2548.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2543.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2434.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2598.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6606_paper_2683.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2469.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2440.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2459.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2453.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2546.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2394.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2495.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2423.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2491.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2520.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2411.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2508.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2446.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2429.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2467.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2419.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2402.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2357.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2405.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2528.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2376.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2374.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2289.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2282.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2291.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2179.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2122.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2378.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2221.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2222.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2306.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2271.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2201.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2456.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2331.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2314.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2399.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2354.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2194.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2237.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2303.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2153.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6612_paper_2691.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2158.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2340.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2259.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2272.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2267.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2364.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2090.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2051.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2071.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2126.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2191.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2178.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2652.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2336.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2352.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2230.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2321.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2118.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2105.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2297.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2154.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2083.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2003.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2131.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1970.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1978.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1888.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1963.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1886.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1916.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1964.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2043.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1985.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2302.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2146.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2089.jpg
#   inflating: splits_v3/augmented_data/paper/aug_6607_paper_2690.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2073.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2113.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2036.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2342.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1747.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1789.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1935.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1748.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1932.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1764.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1771.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1908.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2144.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1873.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2062.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1774.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1729.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1809.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1763.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1703.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1842.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1799.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1738.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2067.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1905.jpg
#   inflating: splits_v3/train/cardboard/cardboard_2192.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1696.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1718.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1929.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1779.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1775.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1734.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1578.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1620.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1583.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1522.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1814.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1739.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1691.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1612.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1506.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1667.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1715.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1744.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1447.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1489.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1593.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1790.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1507.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1665.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1511.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1544.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1499.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1490.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1587.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1500.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1745.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1486.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1891.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1474.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1638.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1699.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1530.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1369.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1621.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1781.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1487.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1433.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1475.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1371.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1521.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1383.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1384.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1412.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1420.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1446.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1466.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1495.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1339.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1411.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1387.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1353.jpg
#   inflating: splits_v3/train/cardboard/cardboard_1630.jpg

# %% [markdown]
# ###Read files

# %% [markdown]
# Since the dataset has been prepared (chosen, resized, splitted), just get each available set (train, validation, test)

# %%
import os
import numpy as np
import cv2

# %% [markdown]
# The labels for each set are the same, so just reuse it:

# %%
labels = sorted(os.listdir('/content/splits_v3/train'))

# %%
labels
# Out:
# ['cardboard', 'compost', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# ####Get train set

# %%
train = dict()

for label in labels:
    img_paths = list(os.listdir('./splits_v3/train/' + label))
    img_paths = map(lambda p: f'./splits_v3/train/{label}/{p}', img_paths)
    train[label] = []
    for path in img_paths:
        img = cv2.imread(path)
        train[label].append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
X_train = []
y_train = []

for encoded_label, label in enumerate(labels):
    y_train += [encoded_label] * len(train[label])
    X_train += train[label]

# %%
y_train = np.array(y_train)
X_train = np.array(X_train)

# %% [markdown]
# Check train set:

# %%
y_train.shape
# Out:
# (3260,)

# %%
X_train.shape
# Out:
# (3260, 300, 400, 3)

# %% [markdown]
# ####Get validation set

# %%
validation = dict()

for label in labels:
    img_paths = list(os.listdir('./splits_v3/validation/' + label))
    img_paths = map(lambda p: f'./splits_v3/validation/{label}/{p}', img_paths)
    validation[label] = []
    for path in img_paths:
        img = cv2.imread(path)
        validation[label].append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
X_dev = []
y_dev = []

for encoded_label, label in enumerate(labels):
    y_dev += [encoded_label] * len(validation[label])
    X_dev += validation[label]

# %%
y_dev = np.array(y_dev)
X_dev = np.array(X_dev)

# %% [markdown]
# Check validation set:

# %%
y_dev.shape
# Out:
# (699,)

# %%
X_dev.shape
# Out:
# (699, 300, 400, 3)

# %% [markdown]
# ####Get test set

# %%
test = dict()

for label in labels:
    img_paths = list(os.listdir('./splits_v3/test/' + label))
    img_paths = map(lambda p: f'./splits_v3/test/{label}/{p}', img_paths)
    test[label] = []
    for path in img_paths:
        img = cv2.imread(path)
        test[label].append(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
X_test = []
y_test = []

for encoded_label, label in enumerate(labels):
    y_test += [encoded_label] * len(test[label])
    X_test += test[label]

# %%
y_test = np.array(y_test)
X_test = np.array(X_test)

# %% [markdown]
# Check test set:

# %%
y_test.shape
# Out:
# (699,)

# %%
X_test.shape
# Out:
# (699, 300, 400, 3)

# %% [markdown]
# ##Feature Engineering

# %%
import tensorflow as tf

# %%
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %% [markdown]
# #### Transfer pretrained model

# %% [markdown]
# ##### Construct model

# %%
# Create the base model from the pre-trained model ResNet50
IMG_SHAPE = (300, 400, 3)
base_model = tf.keras.applications.mobilenet_v2.MobileNetV2(input_shape = IMG_SHAPE,
                                         include_top = False,
                                         weights = 'imagenet')
base_model.trainable = False
base_model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 300, 400, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 150, 200, 32  864         ['input_1[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 150, 200, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 150, 200, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 150, 200, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 150, 200, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 150, 200, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 150, 200, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 150, 200, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 150, 200, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 150, 200, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 150, 200, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 151, 201, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 75, 100, 96)  864        ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 75, 100, 96)  384        ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 75, 100, 96)  0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 75, 100, 24)  2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 75, 100, 24)  96         ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 75, 100, 144  3456        ['block_1_project_BN[0][0]']
#                                 )
#
#  block_2_expand_BN (BatchNormal  (None, 75, 100, 144  576        ['block_2_expand[0][0]']
#  ization)                       )
#
#  block_2_expand_relu (ReLU)     (None, 75, 100, 144  0           ['block_2_expand_BN[0][0]']
#                                 )
#
#  block_2_depthwise (DepthwiseCo  (None, 75, 100, 144  1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          )
#
#  block_2_depthwise_BN (BatchNor  (None, 75, 100, 144  576        ['block_2_depthwise[0][0]']
#  malization)                    )
#
#  block_2_depthwise_relu (ReLU)  (None, 75, 100, 144  0           ['block_2_depthwise_BN[0][0]']
#                                 )
#
#  block_2_project (Conv2D)       (None, 75, 100, 24)  3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 75, 100, 24)  96         ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 75, 100, 24)  0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 75, 100, 144  3456        ['block_2_add[0][0]']
#                                 )
#
#  block_3_expand_BN (BatchNormal  (None, 75, 100, 144  576        ['block_3_expand[0][0]']
#  ization)                       )
#
#  block_3_expand_relu (ReLU)     (None, 75, 100, 144  0           ['block_3_expand_BN[0][0]']
#                                 )
#
#  block_3_pad (ZeroPadding2D)    (None, 77, 101, 144  0           ['block_3_expand_relu[0][0]']
#                                 )
#
#  block_3_depthwise (DepthwiseCo  (None, 38, 50, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 38, 50, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 38, 50, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 38, 50, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 38, 50, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 38, 50, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 38, 50, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 38, 50, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 38, 50, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 38, 50, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 38, 50, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 38, 50, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 38, 50, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 38, 50, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 38, 50, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 38, 50, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 38, 50, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 38, 50, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 38, 50, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 38, 50, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 38, 50, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 38, 50, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 38, 50, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 38, 50, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 38, 50, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 38, 50, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 39, 51, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 19, 25, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 19, 25, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 19, 25, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 19, 25, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 19, 25, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 19, 25, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 19, 25, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 19, 25, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 19, 25, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 19, 25, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 19, 25, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 19, 25, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 19, 25, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 19, 25, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 19, 25, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 19, 25, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 19, 25, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 19, 25, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 19, 25, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 19, 25, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 19, 25, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 19, 25, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 19, 25, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 19, 25, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 19, 25, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 19, 25, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 19, 25, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 19, 25, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 19, 25, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 19, 25, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 19, 25, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 19, 25, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 19, 25, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 19, 25, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 19, 25, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 19, 25, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 19, 25, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 19, 25, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 19, 25, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 19, 25, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 19, 25, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 19, 25, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 19, 25, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 19, 25, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 19, 25, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 19, 25, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 19, 25, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 19, 25, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 19, 25, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 19, 25, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 19, 25, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 19, 25, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 19, 25, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 19, 25, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 19, 25, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 19, 25, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 19, 25, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 19, 25, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 19, 25, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 19, 25, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 19, 25, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 21, 27, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 10, 13, 576)  5184       ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 10, 13, 576)  2304       ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 10, 13, 576)  0          ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 10, 13, 160)  92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 10, 13, 160)  640        ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 10, 13, 960)  153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 10, 13, 960)  3840       ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 10, 13, 960)  0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 10, 13, 960)  8640       ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 10, 13, 960)  3840       ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 10, 13, 960)  0          ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 10, 13, 160)  153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 10, 13, 160)  640        ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 10, 13, 160)  0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 10, 13, 960)  153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 10, 13, 960)  3840       ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 10, 13, 960)  0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 10, 13, 960)  8640       ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 10, 13, 960)  3840       ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 10, 13, 960)  0          ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 10, 13, 160)  153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 10, 13, 160)  640        ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 10, 13, 160)  0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 10, 13, 960)  153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 10, 13, 960)  3840       ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 10, 13, 960)  0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 10, 13, 960)  8640       ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 10, 13, 960)  3840       ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 10, 13, 960)  0          ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 10, 13, 320)  307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 10, 13, 320)  1280       ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 10, 13, 1280  409600      ['block_16_project_BN[0][0]']
#                                 )
#
#  Conv_1_bn (BatchNormalization)  (None, 10, 13, 1280  5120       ['Conv_1[0][0]']
#                                 )
#
#  out_relu (ReLU)                (None, 10, 13, 1280  0           ['Conv_1_bn[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# __________________________________________________________________________________________________

# %%
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D()
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Funct  (None, 10, 13, 1280)     2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
# =================================================================
# Total params: 2,257,984
# Trainable params: 0
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ##### Save FE model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !mkdir pretrained_models

# %%
# %cd pretrained_models
# Out:
# /content/drive/MyDrive/pretrained_models

# %%
tf.keras.models.save_model(model, 'MobileNetV2_SVMFE', save_format='h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #### Feature Extraction

# %%
del train, test, validation

# %%
X_train_fe = model.predict(X_train)
X_test_fe = model.predict(X_test)
X_dev_fe = model.predict(X_dev)
# Out:
# 102/102 [==============================] - 17s 85ms/step
# 22/22 [==============================] - 3s 119ms/step
# 22/22 [==============================] - 2s 77ms/step

# %% [markdown]
# #### Explore results

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(X_train_fe)
df['target'] = y_train

corr_with_target = df.drop(columns='target').corrwith(df['target'])
# fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

sns.heatmap(pd.DataFrame(corr_with_target))
# ax1.set_title('Correlation with target value')
plt.title("Correlation of each column with target");
print(f"min: {corr_with_target.min()}, max: {corr_with_target.max()}")
# Out:
# min: -0.27806503461145843, max: 0.22954108497509895

# %%
corr_with_target.min(), corr_with_target.max()
# Out:
# (-0.27806503461145843, 0.22954108497509895)

# %%
plt.hist(corr_with_target)
# Out:
# (array([ 17.,  43.,  71., 135., 301., 405., 213.,  71.,  20.,   4.]),
#  array([-0.27806503, -0.22730442, -0.17654381, -0.1257832 , -0.07502259,
#         -0.02426197,  0.02649864,  0.07725925,  0.12801986,  0.17878047,
#          0.22954108]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Shuffle dataset

# %%
from sklearn.utils import shuffle
X_train_fe, y_train = shuffle(X_train_fe, y_train, random_state=7)
X_dev_fe, y_dev = shuffle(X_dev_fe, y_dev, random_state=7)
X_test_fe, y_test = shuffle(X_test_fe, y_test, random_state=7)

# %% [markdown]
# ### Optional: Drop low correlated columns
#
# Goal: to take less time training

# %%
# indices = [i for i, c in enumerate(corr_with_target) if -0.02 < c < 0.02 ]

# %%
# np.delete(X_train_fe, indices, axis=1).shape
# Out:
# (3260, 1366)

# %%
# X_train_fe = np.delete(X_train_fe, indices, axis=1)
# X_dev_fe = np.delete(X_dev_fe, indices, axis=1)
# X_test_fe = np.delete(X_test_fe, indices, axis=1)

# %% [markdown]
# ##Hyperparameter Tuning

# %%
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

# %%
X_traindev = np.concatenate([X_train_fe, X_dev_fe], axis = 0)

# %%
y_traindev = np.concatenate([y_train, y_dev], axis = 0)

# %%
param_grid = {'C': np.logspace(1, 3, 3),
              'gamma': np.logspace(-4, 0, 5),
              'kernel': ['rbf']}

cv = StratifiedShuffleSplit(n_splits=3, test_size=0.1275, random_state=42)

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3, cv=cv)

grid.fit(X_traindev, y_traindev)

print(
    "The best parameters are %s with a score of %0.2f"
    % (grid.best_params_, grid.best_score_)
)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [CV 1/3] END ..C=10.0, gamma=0.0001, kernel=rbf;, score=0.549 total time=   8.4s
# [CV 2/3] END ..C=10.0, gamma=0.0001, kernel=rbf;, score=0.568 total time=   9.1s
# [CV 3/3] END ..C=10.0, gamma=0.0001, kernel=rbf;, score=0.539 total time=   9.1s
# [CV 1/3] END ...C=10.0, gamma=0.001, kernel=rbf;, score=0.675 total time=   7.3s
# [CV 2/3] END ...C=10.0, gamma=0.001, kernel=rbf;, score=0.679 total time=   7.3s
# [CV 3/3] END ...C=10.0, gamma=0.001, kernel=rbf;, score=0.655 total time=   6.9s
# [CV 1/3] END ....C=10.0, gamma=0.01, kernel=rbf;, score=0.770 total time=  10.7s
# [CV 2/3] END ....C=10.0, gamma=0.01, kernel=rbf;, score=0.745 total time=   9.5s
# [CV 3/3] END ....C=10.0, gamma=0.01, kernel=rbf;, score=0.741 total time=  10.1s
# [CV 1/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  13.1s
# [CV 2/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.442 total time=  13.2s
# [CV 3/3] END .....C=10.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  13.6s
# [CV 1/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  14.0s
# [CV 2/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.154 total time=  13.6s
# [CV 3/3] END .....C=10.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  13.5s
# [CV 1/3] END .C=100.0, gamma=0.0001, kernel=rbf;, score=0.640 total time=   6.8s
# [CV 2/3] END .C=100.0, gamma=0.0001, kernel=rbf;, score=0.657 total time=   7.1s
# [CV 3/3] END .C=100.0, gamma=0.0001, kernel=rbf;, score=0.644 total time=   6.9s
# [CV 1/3] END ..C=100.0, gamma=0.001, kernel=rbf;, score=0.675 total time=   6.5s
# [CV 2/3] END ..C=100.0, gamma=0.001, kernel=rbf;, score=0.681 total time=   6.9s
# [CV 3/3] END ..C=100.0, gamma=0.001, kernel=rbf;, score=0.697 total time=   6.2s
# [CV 1/3] END ...C=100.0, gamma=0.01, kernel=rbf;, score=0.770 total time=   9.9s
# [CV 2/3] END ...C=100.0, gamma=0.01, kernel=rbf;, score=0.747 total time=  10.2s
# [CV 3/3] END ...C=100.0, gamma=0.01, kernel=rbf;, score=0.741 total time=   9.2s
# [CV 1/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  13.0s
# [CV 2/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.442 total time=  13.1s
# [CV 3/3] END ....C=100.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  13.3s
# [CV 1/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  13.2s
# [CV 2/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.154 total time=  13.4s
# [CV 3/3] END ....C=100.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  13.5s
# [CV 1/3] END C=1000.0, gamma=0.0001, kernel=rbf;, score=0.630 total time=   6.2s
# [CV 2/3] END C=1000.0, gamma=0.0001, kernel=rbf;, score=0.661 total time=   7.2s
# [CV 3/3] END C=1000.0, gamma=0.0001, kernel=rbf;, score=0.679 total time=   6.3s
# [CV 1/3] END .C=1000.0, gamma=0.001, kernel=rbf;, score=0.689 total time=   7.2s
# [CV 2/3] END .C=1000.0, gamma=0.001, kernel=rbf;, score=0.685 total time=   6.8s
# [CV 3/3] END .C=1000.0, gamma=0.001, kernel=rbf;, score=0.697 total time=   7.1s
# [CV 1/3] END ..C=1000.0, gamma=0.01, kernel=rbf;, score=0.770 total time=   9.6s
# [CV 2/3] END ..C=1000.0, gamma=0.01, kernel=rbf;, score=0.747 total time=   9.8s
# [CV 3/3] END ..C=1000.0, gamma=0.01, kernel=rbf;, score=0.741 total time=  10.0s
# [CV 1/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  12.7s
# [CV 2/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.442 total time=  12.8s
# [CV 3/3] END ...C=1000.0, gamma=0.1, kernel=rbf;, score=0.420 total time=  12.8s
# [CV 1/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  13.1s
# [CV 2/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.154 total time=  13.0s
# [CV 3/3] END ...C=1000.0, gamma=1.0, kernel=rbf;, score=0.156 total time=  13.0s
# The best parameters are {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} with a score of 0.75

# %% [markdown]
# The best parameters are {'C': 100.0, 'gamma': 0.01, 'kernel': 'rbf'} with a score of 0.75

# %% [markdown]
# ##Create a model

# %%
clf = SVC(C=100, gamma=0.01, kernel='rbf')

# %%
clf.fit(X_train_fe, y_train)
# Out:
# SVC(C=100, gamma=0.01)

# %%
import pickle
pickle.dump(clf, open('SVM_MobileNetV2.pkl', 'wb'))

# %% [markdown]
# ##Prediction

# %% [markdown]
# ##Evaluation metrics

# %% [markdown]
# ### Train/dev eval

# %%
from sklearn import metrics
print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_train, clf.predict(X_train_fe))}\n"
)
# Out:
# Classification report for classifier SVC(C=100, gamma=0.01):
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       431
#            1       1.00      1.00      1.00       507
#            2       1.00      1.00      1.00       413
#            3       1.00      1.00      1.00       477
#            4       1.00      1.00      1.00       457
#            5       1.00      1.00      1.00       473
#            6       1.00      1.00      1.00       502
#
#     accuracy                           1.00      3260
#    macro avg       1.00      1.00      1.00      3260
# weighted avg       1.00      1.00      1.00      3260

# %%
from sklearn import metrics
print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_dev, clf.predict(X_dev_fe))}\n"
)
# Out:
# Classification report for classifier SVC(C=100, gamma=0.01):
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        92
#            1       0.85      0.89      0.87       109
#            2       0.66      0.64      0.65        89
#            3       0.70      0.68      0.69       102
#            4       0.83      0.82      0.82        98
#            5       0.64      0.70      0.67       102
#            6       0.71      0.62      0.66       107
#
#     accuracy                           0.74       699
#    macro avg       0.74      0.74      0.74       699
# weighted avg       0.74      0.74      0.74       699

# %% [markdown]
# ### Test eval

# %%
y_pred = clf.predict(X_test_fe)

# %%
from sklearn import metrics
print(
    f"Classification report for classifier {clf}:\n"
    f"{metrics.classification_report(y_test, y_pred, target_names=labels)}\n"
)
# Out:
# Classification report for classifier SVC(C=100, gamma=0.01):
#               precision    recall  f1-score   support
#
#    cardboard       0.84      0.85      0.84        93
#      compost       0.81      0.85      0.83       109
#        glass       0.79      0.75      0.77        88
#        metal       0.77      0.75      0.76       102
#        paper       0.76      0.79      0.77        98
#      plastic       0.66      0.69      0.68       101
#        trash       0.63      0.58      0.61       108
#
#     accuracy                           0.75       699
#    macro avg       0.75      0.75      0.75       699
# weighted avg       0.75      0.75      0.75       699

# %%
import matplotlib.pyplot as plt
disp = metrics.ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
disp.figure_.suptitle("Confusion Matrix")

plt.show();

# %%
labels
# Out:
# ['cardboard', 'compost', 'glass', 'metal', 'paper', 'plastic', 'trash']
